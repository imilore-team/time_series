# %% [markdown]
# ## Установка библиотека

# %%
# !pip install statsmodels >> None
# !pip install prophet >> None
# !pip install neuralprophet[live] >> None
# !pip install numpy==1.24.1 >> None

# %%
import matplotlib.pyplot as plt  # plots
import numpy as np  # vectors and matrices
import pandas as pd  # tables and data manipulations
import seaborn as sns  # more plots
from prophet import Prophet
from neuralprophet import NeuralProphet, set_log_level

set_log_level("ERROR")

sns.set()

import warnings  
from itertools import product  # some useful functions

import scipy.stats as scs
import statsmodels.api as sm
import statsmodels.formula.api as smf  # statistics and econometrics
import statsmodels.tsa.api as smt
from dateutil.relativedelta import \
    relativedelta  # working with dates with style
from scipy.optimize import minimize  # for function minimization
from tqdm.notebook import tqdm
from sklearn.metrics import (mean_absolute_error, mean_squared_error,
                             mean_squared_log_error, median_absolute_error,
                             r2_score)

warnings.filterwarnings("ignore") # `do not disturbe` mode

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Предобработка, визуализацияя

# %%
# !pip3 install lxml
# Out:
# Requirement already satisfied: lxml in c:\python\python310\lib\site-packages (4.9.2)
#
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_html("trends_sirius.html", parse_dates=True) # delimiter=",",
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [120], in <cell line: 1>()
# ----> 1 df = pd.read_html("trends_sirius.html", parse_dates=True)
#
# File C:\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python\Python310\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File C:\Python\Python310\lib\site-packages\pandas\io\html.py:915, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913 retained = None
#     914 for flav in flavor:
# --> 915     parser = _parser_dispatch(flav)
#     916     p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918     try:
#
# File C:\Python\Python310\lib\site-packages\pandas\io\html.py:872, in _parser_dispatch(flavor)
#     870 else:
#     871     if not _HAS_LXML:
# --> 872         raise ImportError("lxml not found, please install it")
#     873 return _valid_parsers[flavor]
#
# ImportError: lxml not found, please install it

# %%
df = pd.read_csv("sirius_trends.csv", delimiter=",", parse_dates=True)
df["clock"] = df["clock"].replace(164117, np.nan)
df.dropna(subset=['clock'], inplace=True)
df["clock"] = df["clock"].map(lambda x: pd.Timestamp(x, unit='s'))
df = df[df.hostid == 10119.0]
df
# Out:
#         itemid               clock num value_min  value_avg  value_max  \
# 0        26231 2021-12-29 12:00:00  60   24.0722    65.1813    85.5262
# 1        26231 2021-12-29 13:00:00  60   30.2988    66.3591    85.7727
# 2        26231 2021-12-29 14:00:00  60   35.5957    69.3803    88.0117
# 3        26231 2021-12-29 15:00:00  60   25.4243    68.7481    86.1221
# 4        26231 2021-12-29 16:00:00  60   34.0265    71.2394    91.2847
# ...        ...                 ...  ..       ...        ...        ...
# 139823   26228 2022-12-29 06:00:00  60    0.0362     0.1075     0.2575
# 139824   26228 2022-12-29 07:00:00  60    0.0125     0.0667     0.3100
# 139825   26228 2022-12-29 08:00:00  60    0.0388     0.3027     1.0050
# 139826   26228 2022-12-29 09:00:00  60    0.1662     0.3725     1.1187
# 139827   26228 2022-12-29 10:00:00  60      0.17     0.3751     0.6512
#
#          hostid                   host  itemid.1  \
# 0       10119.0  ISUGT_OK_APLICATION_1   26231.0
# 1       10119.0  ISUGT_OK_APLICATION_1   26231.0
# 2       10119.0  ISUGT_OK_APLICATION_1   26231.0
# 3       10119.0  ISUGT_OK_APLICATION_1   26231.0
# 4       10119.0  ISUGT_OK_APLICATION_1   26231.0
# ...         ...                    ...       ...
# 139823  10119.0  ISUGT_OK_APLICATION_1   26228.0
# 139824  10119.0  ISUGT_OK_APLICATION_1   26228.0
# 139825  10119.0  ISUGT_OK_APLICATION_1   26228.0
# 139826  10119.0  ISUGT_OK_APLICATION_1   26228.0
# 139827  10119.0  ISUGT_OK_APLICATION_1   26228.0
#
#                                            name units  \
# 0                                   CPU $2 time     %
# 1                                   CPU $2 time     %
# 2                                   CPU $2 time     %
# 3                                   CPU $2 time     %
# 4                                   CPU $2 time     %
# ...                                         ...   ...
# 139823  Processor load (1 min average per core)   NaN
# 139824  Processor load (1 min average per core)   NaN
# 139825  Processor load (1 min average per core)   NaN
# 139826  Processor load (1 min average per core)   NaN
# 139827  Processor load (1 min average per core)   NaN
#
#                                 key_  \
# 0             system.cpu.util[,idle]
# 1             system.cpu.util[,idle]
# 2             system.cpu.util[,idle]
# 3             system.cpu.util[,idle]
# 4             system.cpu.util[,idle]
# ...                              ...
# 139823  system.cpu.load[percpu,avg1]
# 139824  system.cpu.load[percpu,avg1]
# 139825  system.cpu.load[percpu,avg1]
# 139826  system.cpu.load[percpu,avg1]
# 139827  system.cpu.load[percpu,avg1]
#
#                                               description
# 0             The time the CPU has spent doing nothing.\r
# 1             The time the CPU has spent doing nothing.\r
# 2             The time the CPU has spent doing nothing.\r
# 3             The time the CPU has spent doing nothing.\r
# 4             The time the CPU has spent doing nothing.\r
# ...                                                   ...
# 139823  The processor load is calculated as system CPU...
# 139824  The processor load is calculated as system CPU...
# 139825  The processor load is calculated as system CPU...
# 139826  The processor load is calculated as system CPU...
# 139827  The processor load is calculated as system CPU...
#
# [139827 rows x 13 columns]

# %%
set(df["hostid"])
# Out:
# {10119.0}

# %%
params = list(set(df["itemid"]))
base_df = df[df.itemid == params[0]].drop(columns=["num", "value_min", "value_max", "hostid", "host", "itemid.1", 
                                                   "units", "key_", "description", "itemid"])
base_df.rename(columns={"value_avg": list(base_df["name"])[0]}, inplace=True)
base_df = base_df.drop(columns=["name"])
base_df
# Out:
#                      clock  Free swap space in %
# 122310 2021-12-29 12:00:00               96.9860
# 122311 2021-12-29 13:00:00               96.9538
# 122312 2021-12-29 14:00:00               96.9672
# 122313 2021-12-29 15:00:00               96.9710
# 122314 2021-12-29 16:00:00               96.9734
# ...                    ...                   ...
# 131064 2022-12-29 06:00:00               97.9360
# 131065 2022-12-29 07:00:00               97.9360
# 131066 2022-12-29 08:00:00               97.9360
# 131067 2022-12-29 09:00:00               97.9360
# 131068 2022-12-29 10:00:00               97.9360
#
# [8759 rows x 2 columns]

# %%
print(len(params))
for param in params[1:]:
    cur_df = df[df.itemid == param].drop(columns=["num", "value_min", "value_max", "hostid", "host", "itemid.1", 
                                                   "units", "key_", "description", "itemid"])
    cur_df.rename(columns={"value_avg": list(cur_df["name"])[0]}, inplace=True)
    cur_df = cur_df.drop(columns=["name"])
    base_df = pd.merge(base_df, cur_df, on='clock', how='inner')
base_df
# Out:
# 16
#                    clock  Free swap space in %  \
# 0    2021-12-29 12:00:00               96.9860
# 1    2021-12-29 13:00:00               96.9538
# 2    2021-12-29 14:00:00               96.9672
# 3    2021-12-29 15:00:00               96.9710
# 4    2021-12-29 16:00:00               96.9734
# ...                  ...                   ...
# 8437 2022-12-29 06:00:00               97.9360
# 8438 2022-12-29 07:00:00               97.9360
# 8439 2022-12-29 08:00:00               97.9360
# 8440 2022-12-29 09:00:00               97.9360
# 8441 2022-12-29 10:00:00               97.9360
#
#       Free inodes on $1 (percentage)_x  Free inodes on $1 (percentage)_y  \
# 0                              96.7293                           99.8723
# 1                              96.7293                           99.8723
# 2                              96.7293                           99.8723
# 3                              96.7293                           99.8723
# 4                              96.7293                           99.8723
# ...                                ...                               ...
# 8437                           97.1591                           99.8723
# 8438                           97.1590                           99.8723
# 8439                           97.1590                           99.8723
# 8440                           97.1589                           99.8723
# 8441                           97.1588                           99.8723
#
#       Free inodes on $1 (percentage)  Processor load (1 min average per core)  \
# 0                            99.9902                                   0.4164
# 1                            99.9902                                   0.3398
# 2                            99.9902                                   0.2929
# 3                            99.9902                                   0.3506
# 4                            99.9902                                   0.3194
# ...                              ...                                      ...
# 8437                         99.9902                                   0.1075
# 8438                         99.9902                                   0.0667
# 8439                         99.9902                                   0.3027
# 8440                         99.9902                                   0.3725
# 8441                         99.9902                                   0.3751
#
#       Free disk space on $1 (percentage)_x  \
# 0                                  37.3175
# 1                                  37.3126
# 2                                  37.3094
# 3                                  37.2992
# 4                                  37.2956
# ...                                    ...
# 8437                               46.9625
# 8438                               46.9608
# 8439                               46.9567
# 8440                               46.9386
# 8441                               46.9356
#
#       Free disk space on $1 (percentage)_y  \
# 0                                  75.7859
# 1                                  75.7859
# 2                                  75.7859
# 3                                  75.7859
# 4                                  75.7859
# ...                                    ...
# 8437                               75.7859
# 8438                               75.7859
# 8439                               75.7859
# 8440                               75.7859
# 8441                               75.7859
#
#       Free disk space on $1 (percentage)  CPU $2 time_x  CPU $2 time_y  \
# 0                                99.6154        65.1813            0.0
# 1                                99.6154        66.3591            0.0
# 2                                99.6154        69.3803            0.0
# 3                                99.6154        68.7481            0.0
# 4                                99.6154        71.2394            0.0
# ...                                  ...            ...            ...
# 8437                             99.6154        88.8297            0.0
# 8438                             99.6154        91.6646            0.0
# 8439                             99.6154        71.3445            0.0
# 8440                             99.6154        65.2412            0.0
# 8441                             99.6154        64.4881            0.0
#
#       CPU $2 time_x  CPU $2 time_y  CPU $2 time_x  CPU $2 time_y  \
# 0            0.5959            0.0         0.6588            0.0
# 1            0.4646            0.0         0.5827            0.0
# 2            0.3506            0.0         0.4766            0.0
# 3            0.3432            0.0         0.4714            0.0
# 4            0.4531            0.0         0.4161            0.0
# ...             ...            ...            ...            ...
# 8437         0.1594            0.0         0.5844            0.0
# 8438         0.1560            0.0         0.4218            0.0
# 8439         0.1300            0.0         0.7362            0.0
# 8440         0.0965            0.0         0.6120            0.0
# 8441         0.0927            0.0         0.6318            0.0
#
#       CPU $2 time_x  CPU $2 time_y
# 0            1.9647        31.5884
# 1            1.8228        30.8428
# 2            1.6848        28.0851
# 3            1.7121        28.6736
# 4            1.6525        26.2155
# ...             ...            ...
# 8437         1.7752         8.6976
# 8438         1.5490         6.1720
# 8439         1.8381        25.8916
# 8440         1.6205        32.3952
# 8441         1.6455        33.1246
#
# [8442 rows x 17 columns]

# %%
base_df.to_csv("df_for_10119_with_all_metrics.csv")

# %%
import seaborn as sns
corr = base_df.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("t90.csv", delimiter=",", parse_dates=True)

# %%
df
# Out:
#       itemid       clock  num  value_min  value_avg  value_max
# 0      26690  1640779200   60     0.3912     0.9491     2.8600
# 1      26690  1640782800   60     0.2750     0.4578     0.7288
# 2      26690  1640786400   60     0.0825     0.2668     0.7412
# 3      26690  1640790000   60     0.0688     0.1656     0.2900
# 4      26690  1640793600   60     0.0825     0.2038     0.3262
# ...      ...         ...  ...        ...        ...        ...
# 8754   26690  1672293600   60     0.7962     1.5824     2.7200
# 8755   26690  1672297200   60     0.5850     1.1263     2.0438
# 8756   26690  1672300800   60     0.6238     1.2200     2.4925
# 8757   26690  1672304400   60     0.3350     0.6282     1.2325
# 8758   26690  1672308000   60     0.5750     1.0178     2.2287
#
# [8759 rows x 6 columns]

# %%
df["clock"] = df["clock"].map(lambda x: pd.Timestamp(x, unit='s'))
# df.set_index("clock", inplace=True)
df = df.drop(columns=["itemid", "num", "value_min", "value_max"])
# df.drop(['Series'], axis=1, inplace=True)
# df.Time = df.Time.map(lambda a: a[:a.find('+')])
df
# Out:
#                    clock  value_avg
# 0    2021-12-29 12:00:00     0.9491
# 1    2021-12-29 13:00:00     0.4578
# 2    2021-12-29 14:00:00     0.2668
# 3    2021-12-29 15:00:00     0.1656
# 4    2021-12-29 16:00:00     0.2038
# ...                  ...        ...
# 8754 2022-12-29 06:00:00     1.5824
# 8755 2022-12-29 07:00:00     1.1263
# 8756 2022-12-29 08:00:00     1.2200
# 8757 2022-12-29 09:00:00     0.6282
# 8758 2022-12-29 10:00:00     1.0178
#
# [8759 rows x 2 columns]

# %%
# df.to_csv("history_one_metric_cleared.csv")

# %%
df.rename(columns={"clock": "ds", "value_avg": "y"}, inplace=True)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.y)
plt.show()

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=200)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
fig1 = m.plot(forecast)
# Out:
# 10:14:33 - cmdstanpy - INFO - Chain [1] start processing
# 10:14:35 - cmdstanpy - INFO - Chain [1] done processing

# %%
m = NeuralProphet(growth="off", weekly_seasonality=False, daily_seasonality=8, learning_rate=0.1)
# metrics = m.fit(df, freq='T')

# %%
# df_future = m.make_future_dataframe(df, periods=3600)
# forecast = m.predict(df_future)
# fig_forecast = m.plot(forecast)
# fig_components = m.plot_components(forecast)
# fig_model = m.plot_parameters()

# %%
df_train, df_test = m.split_df(df, freq="T", valid_p=0.10)

metrics = m.fit(df_train, freq="T", validation_df=df_test)
# Out:
# Missing logger folder: C:\Users\User\Documents\projects\time_series\lightning_logs
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %%
forecast = m.predict(df_test)
fig_param = m.plot_parameters()
fig_prediction = m.plot(forecast[-48:])
# Out:
# Predicting: 247it [00:00, ?it/s]

# %%
forecast = m.predict(df)
fig = m.plot(forecast)
# Out:
# Predicting: 247it [00:00, ?it/s]

# %%
def plotMovingAverage(
    series, window, plot_intervals=False, scale=1.96, plot_anomalies=False
):

    """
        series - dataframe with timeseries
        window - rolling window size
        plot_intervals - show confidence intervals
        plot_anomalies - show anomalies

    """
    rolling_mean = series.rolling(window=window).mean()

    plt.figure(figsize=(15, 5))
    plt.title("Moving average\n window size = {}".format(window))
    plt.plot(rolling_mean, "g", label="Rolling mean trend")

    # Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bond = rolling_mean - (mae + scale * deviation)
        upper_bond = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bond, "r--", label="Upper Bond / Lower Bond")
        plt.plot(lower_bond, "r--")

        # Having the intervals, find abnormal values
        if plot_anomalies:
            anomalies = pd.DataFrame(index=series.index, columns=series.columns)
            anomalies[series < lower_bond] = series[series < lower_bond]
            anomalies[series > upper_bond] = series[series > upper_bond]
            plt.plot(anomalies, "ro", markersize=10)

    # plt.plot(series[window:], label="Actual values")
    plt.legend(loc="upper left")
    plt.grid(True)

# %%
plotMovingAverage(df.Value, 4)

# %%
df1 = df
df1.set_index('ds', inplace=True)

# %%
# импортируем функцию seasonal_decompose из statsmodels 
from statsmodels.tsa.seasonal import seasonal_decompose
 
# задаем размер графика
from pylab import rcParams
rcParams['figure.figsize'] = 11, 9
 
# применяем функцию к данным о перевозках
decompose = seasonal_decompose(x=df1, period=100)
decompose.plot()
 
plt.show()

# %%
from darts.models import ExponentialSmoothing

model = ExponentialSmoothing()
model.fit(train)
prediction = model.predict(len(val), num_samples=1000)

# %%
import matplotlib.pyplot as plt

series.plot()
prediction.plot(label="forecast", low_quantile=0.05, high_quantile=0.95)
plt.legend()
